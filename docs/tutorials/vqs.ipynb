# %% [markdown]
# #

# %%
import jax

from queso.sensors import Sensor

# %%
sensor = Sensor(
    n = 4,
    k = 4,
    kwargs = dict(
        preparation='hardware_efficient_ansatz',
    )
)

# %%
sensor.circuit
# Out:
# <bound method Sensor.circuit of <queso.sensors.tc.sensor.Sensor object at 0x000001EE57010210>>

# %%
key = jax.random.PRNGKey(10)
theta = jax.random.uniform(key, sensor.theta.shape)
phi = sensor.phi
mu = sensor.mu

# %%
sensor.circuit(theta, phi, mu).draw()
# Out:
#      ┌─────────────┐┌─────────────┐    ┌─────────────┐┌──────────────┐»
# q_0: ┤ Ry(0.58459) ├┤ Rz(0.67938) ├──■─┤ Ry(0.77783) ├┤ Rz(0.026124) ├»
#      └┬────────────┤├─────────────┴┐ │ └─────────────┘├─────────────┬┘»
# q_1: ─┤ Ry(0.7524) ├┤ Rz(0.059104) ├─■────────■───────┤ Ry(0.41726) ├─»
#      ┌┴────────────┤├─────────────┬┘          │       ├─────────────┤ »
# q_2: ┤ Ry(0.58323) ├┤ Rz(0.70296) ├──■────────■───────┤ Ry(0.21947) ├─»
#      ├─────────────┤├─────────────┤  │ ┌─────────────┐├─────────────┤ »
# q_3: ┤ Ry(0.73031) ├┤ Rz(0.65917) ├──■─┤ Ry(0.17433) ├┤ Rz(0.25059) ├─»
#      └─────────────┘└─────────────┘    └─────────────┘└─────────────┘ »
# c: 4/═════════════════════════════════════════════════════════════════»
#                                                                       »
# «                       ┌─────────────┐┌─────────────┐                  »
# «q_0: ────────────────■─┤ Ry(0.52372) ├┤ Rz(0.88688) ├────────────────■─»
# «     ┌─────────────┐ │ └─────────────┘├─────────────┤┌─────────────┐ │ »
# «q_1: ┤ Rz(0.47489) ├─■────────■───────┤ Ry(0.88017) ├┤ Rz(0.54072) ├─■─»
# «     ├─────────────┤          │       ├─────────────┤├─────────────┤   »
# «q_2: ┤ Rz(0.87426) ├─■────────■───────┤ Ry(0.97156) ├┤ Rz(0.43115) ├─■─»
# «     └─────────────┘ │  ┌────────────┐├─────────────┤└─────────────┘ │ »
# «q_3: ────────────────■──┤ Ry(0.7974) ├┤ Rz(0.59239) ├────────────────■─»
# «                        └────────────┘└─────────────┘                  »
# «c: 4/══════════════════════════════════════════════════════════════════»
# «                                                                       »
# «     ┌─────────────┐ ┌─────────────┐                    ┌───────────┐ »
# «q_0: ┤ Ry(0.77585) ├─┤ Rz(0.80488) ├─────────────────■──┤ Ry(0.341) ├─»
# «     └─────────────┘ ├─────────────┤┌─────────────┐  │  └───────────┘ »
# «q_1: ───────■────────┤ Ry(0.14077) ├┤ Rz(0.75018) ├──■────────■───────»
# «            │        ├─────────────┤├─────────────┴┐          │       »
# «q_2: ───────■────────┤ Ry(0.91653) ├┤ Rz(0.066056) ├─■────────■───────»
# «     ┌──────────────┐├─────────────┤└──────────────┘ │ ┌─────────────┐»
# «q_3: ┤ Ry(0.021768) ├┤ Rz(0.91912) ├─────────────────■─┤ Ry(0.74058) ├»
# «     └──────────────┘└─────────────┘                   └─────────────┘»
# «c: 4/═════════════════════════════════════════════════════════════════»
# «                                                                      »
# «      ┌────────────┐                  ░ ┌───────┐ ░ ┌───┐ ░
# «q_0: ─┤ Rz(0.3001) ├──────────────────░─┤ Rz(0) ├─░─┤ r ├─░─
# «     ┌┴────────────┴┐ ┌────────────┐  ░ ├───────┤ ░ ├───┤ ░
# «q_1: ┤ Ry(0.060449) ├─┤ Rz(0.4686) ├──░─┤ Rz(0) ├─░─┤ r ├─░─
# «     ├─────────────┬┘┌┴────────────┴┐ ░ ├───────┤ ░ ├───┤ ░
# «q_2: ┤ Ry(0.21371) ├─┤ Rz(0.046417) ├─░─┤ Rz(0) ├─░─┤ r ├─░─
# «     ├─────────────┤ └──────────────┘ ░ ├───────┤ ░ ├───┤ ░
# «q_3: ┤ Rz(0.69928) ├──────────────────░─┤ Rz(0) ├─░─┤ r ├─░─
# «     └─────────────┘                  ░ └───────┘ ░ └───┘ ░
# «c: 4/═══════════════════════════════════════════════════════
# «

# %%
sensor.circuit(theta, phi, mu).sample()
# Out:
# (Array([1., 0., 0., 0.], dtype=float64), Array(0.12007089, dtype=float64))

# %%
sensor.cfi(theta, phi, mu)
# Out:
# Array(4.27833761e-32, dtype=float64)
